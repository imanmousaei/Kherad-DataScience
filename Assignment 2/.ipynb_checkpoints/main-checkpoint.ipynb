# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
import datetime
import csv
import sys

# %%
# load datasets
dataset = pd.read_csv('datasets/owid-covid-data.csv', parse_dates=['date'])
dataset.head(10)
# Out:
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan 2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan 2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan 2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan 2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan 2020-02-28          5.0        0.0
# 5      AFG      Asia  Afghanistan 2020-02-29          5.0        0.0
# 6      AFG      Asia  Afghanistan 2020-03-01          5.0        0.0
# 7      AFG      Asia  Afghanistan 2020-03-02          5.0        0.0
# 8      AFG      Asia  Afghanistan 2020-03-03          5.0        0.0
# 9      AFG      Asia  Afghanistan 2020-03-04          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# ...

# %%
dataset.tail(10)
# Out:
#        iso_code continent  location       date  total_cases  new_cases  \
# 133798      ZWE    Africa  Zimbabwe 2021-11-07     133187.0       19.0
# 133799      ZWE    Africa  Zimbabwe 2021-11-08     133205.0       18.0
# 133800      ZWE    Africa  Zimbabwe 2021-11-09     133242.0       37.0
# 133801      ZWE    Africa  Zimbabwe 2021-11-10     133302.0       60.0
# 133802      ZWE    Africa  Zimbabwe 2021-11-11     133329.0       27.0
# 133803      ZWE    Africa  Zimbabwe 2021-11-12     133329.0        0.0
# 133804      ZWE    Africa  Zimbabwe 2021-11-13     133393.0       64.0
# 133805      ZWE    Africa  Zimbabwe 2021-11-14     133428.0       35.0
# 133806      ZWE    Africa  Zimbabwe 2021-11-15     133438.0       10.0
# 133807      ZWE    Africa  Zimbabwe 2021-11-16     133505.0       67.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 133798              30.000        4685.0         0.0                1.000
# ...

# %%
dataset.sort_values(by='location')
dataset.sort_values(by='date')
dataset.head(10)
# Out:
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan 2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan 2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan 2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan 2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan 2020-02-28          5.0        0.0
# 5      AFG      Asia  Afghanistan 2020-02-29          5.0        0.0
# 6      AFG      Asia  Afghanistan 2020-03-01          5.0        0.0
# 7      AFG      Asia  Afghanistan 2020-03-02          5.0        0.0
# 8      AFG      Asia  Afghanistan 2020-03-03          5.0        0.0
# 9      AFG      Asia  Afghanistan 2020-03-04          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133808 entries, 0 to 133807
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    133808 non-null  object
#  1   continent                                   125269 non-null  object
#  2   location                                    133808 non-null  object
#  3   date                                        133808 non-null  datetime64[ns]
#  4   total_cases                                 126445 non-null  float64
#  5   new_cases                                   126443 non-null  float64
#  6   new_cases_smoothed                          125400 non-null  float64
#  7   total_deaths                                115288 non-null  float64
#  8   new_deaths                                  115484 non-null  float64
# ...

# %%
# fill null fields with previous valid value
dataset.fillna(method='ffill', inplace=True)

# fill remaining nulls with next valid value
dataset.fillna(method='bfill', inplace=True)

# %%
dataset.isna().sum()
dataset.head(10)
# Out:
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan 2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan 2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan 2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan 2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan 2020-02-28          5.0        0.0
# 5      AFG      Asia  Afghanistan 2020-02-29          5.0        0.0
# 6      AFG      Asia  Afghanistan 2020-03-01          5.0        0.0
# 7      AFG      Asia  Afghanistan 2020-03-02          5.0        0.0
# 8      AFG      Asia  Afghanistan 2020-03-03          5.0        0.0
# 9      AFG      Asia  Afghanistan 2020-03-04          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0               0.714           1.0         1.0                  0.0  ...
# ...

# %%
# get rid of redundant columns
dataset.drop(columns=['new_cases_smoothed', 'new_deaths_smoothed'], inplace=True)
dataset.head(10)
# Out:
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan 2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan 2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan 2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan 2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan 2020-02-28          5.0        0.0
# 5      AFG      Asia  Afghanistan 2020-02-29          5.0        0.0
# 6      AFG      Asia  Afghanistan 2020-03-01          5.0        0.0
# 7      AFG      Asia  Afghanistan 2020-03-02          5.0        0.0
# 8      AFG      Asia  Afghanistan 2020-03-03          5.0        0.0
# 9      AFG      Asia  Afghanistan 2020-03-04          5.0        0.0
#
#    total_deaths  new_deaths  total_cases_per_million  new_cases_per_million  \
# 0           1.0         1.0                    0.126                  0.126
# ...

# %%
# dataset.plot(kind='bar', title="1-1")

# %%
n = 10000
dataset.shape
# Out:
# (133808, 65)

# %%
plt.plot(dataset['date'][:n], dataset['new_cases'][:n])
plt.title('Plot 1-1', fontsize = 20)
plt.grid()
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# the previous plot is not properly distributed. So we shuffle and take the first n(because my laptop cant handle to plot all rows)
from sklearn.utils import shuffle
dataset = shuffle(dataset)
mini_dataset = dataset.sample(frac=0.1)

# %%
plt.scatter(mini_dataset['date'], mini_dataset['new_cases'], marker='.')
plt.title('Plot 1-2', fontsize = 20)
plt.grid()
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.scatter(mini_dataset['date'], mini_dataset['new_vaccinations'], marker='.')
plt.title('Plot 3-1', fontsize = 20)
plt.grid()
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.scatter(dataset['date'], dataset['total_vaccinations'], marker='.', color='b')
plt.scatter(dataset['date'], dataset['new_cases'], marker='.', color='r')
plt.title('Plot 3-1', fontsize = 20)
plt.grid()
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
dataset.hist()
# Out:
# array([[<AxesSubplot:title={'center':'date'}>,
#         <AxesSubplot:title={'center':'total_cases'}>,
#         <AxesSubplot:title={'center':'new_cases'}>,
#         <AxesSubplot:title={'center':'total_deaths'}>,
#         <AxesSubplot:title={'center':'new_deaths'}>,
#         <AxesSubplot:title={'center':'total_cases_per_million'}>,
#         <AxesSubplot:title={'center':'new_cases_per_million'}>,
#         <AxesSubplot:title={'center':'new_cases_smoothed_per_million'}>],
#        [<AxesSubplot:title={'center':'total_deaths_per_million'}>,
#         <AxesSubplot:title={'center':'new_deaths_per_million'}>,
#         <AxesSubplot:title={'center':'new_deaths_smoothed_per_million'}>,
#         <AxesSubplot:title={'center':'reproduction_rate'}>,
#         <AxesSubplot:title={'center':'icu_patients'}>,
#         <AxesSubplot:title={'center':'icu_patients_per_million'}>,
#         <AxesSubplot:title={'center':'hosp_patients'}>,
# ...

# %%
mini_dataset.shape
# Out:
# (13381, 65)

# %%
sns.histplot(mini_dataset['new_cases'], kde=True)
# Out:
# <AxesSubplot:xlabel='new_cases', ylabel='Count'>

# %%
important_cols1 = [
    'new_cases', 
    'new_deaths', 
    'new_vaccinations', 
    'total_vaccinations', 
    'icu_patients', 
    'hosp_patients', 
    'aged_65_older', 
    'aged_70_older', 
]
corr = dataset[important_cols1].corr()
ax = plt.axes()

sns.heatmap(corr, cmap="Blues", annot=True)
ax.set_title('plot 3-2')
plt.show()

# %%
important_cols2 = [
    'new_cases', 
    'new_deaths', 
    'new_vaccinations', 
    'total_vaccinations', 
    'handwashing_facilities', 
    'life_expectancy', 
    'human_development_index', 
    'excess_mortality'
]

corr = dataset[important_cols2].corr()
ax = plt.axes()

sns.heatmap(corr, cmap="Blues", annot=True)
ax.set_title('plot 3-3')
plt.show()

# %%
    
important_cols3 = [
    'new_cases', 
    'new_deaths', 
    'new_vaccinations', 
    'total_vaccinations', 
    'extreme_poverty', 
    'diabetes_prevalence', 
    'female_smokers', 
    'male_smokers', 
]

corr = dataset[important_cols3].corr()
ax = plt.axes()

sns.heatmap(corr, cmap="Blues", annot=True)
ax.set_title('plot 3-4')
plt.show()

# %%
plt.scatter(mini_dataset['date'], mini_dataset['new_deaths']/mini_dataset['new_cases'], marker='.')
plt.title('Plot 4-1', fontsize = 20)
plt.grid()
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.
