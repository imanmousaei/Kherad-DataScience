# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
import sys

# %%
# load datasets
dataset_2014 = pd.read_csv('datasets/Crime_Data_2014.csv')
# bnb.sort_values(by='host_id')
# dataset_size = len(bnb['id'])
# print('dataset_size = ', dataset_size)
dataset_2014.head()
# Out:
# /home/iman/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   INCIDENT_NUMBER        DATE_REPORTED         DATE_OCCURED  \
# 0    80-14-048074  2014-06-30 10:46:00  2014-06-29 21:00:00
# 1    80-14-004033  2014-01-16 18:20:00  2014-01-16 14:45:00
# 2    80-14-057665  2014-08-03 07:48:17  2014-07-28 15:54:00
# 3    80-14-092782  2014-12-02 22:50:27  2014-11-28 20:00:00
# 4    80-14-092782  2014-12-02 22:50:27  2014-11-28 20:00:00
#
#                                             UOR_DESC     CRIME_TYPE  \
# 0                RECEIVING STOLEN PROPERTY (FIREARM)  THEFT/LARCENY
# 1                RECEIVING STOLEN PROPERTY (FIREARM)  THEFT/LARCENY
# 2              RECEIVING STOLEN PROPERTY U/$500 MISD  THEFT/LARCENY
# 3                RECEIVING STOLEN PROPERTY U/$10,000  THEFT/LARCENY
# ...

# %%
# plt.rcParams["figure.figsize"] = [20, 10]
# plt.rcParams["figure.autolayout"] = True

x = bnb['host_id']
y = bnb['price']

plt.scatter(x, y, label = "price")
plt.legend()
plt.show()

# %%
# plt.plot(x, y3, label = "number_of_reviews")
# plt.plot(x, y4, label = "availability_365")

x = bnb['host_id']
y = bnb['availability_365']

plt.scatter(x, y, color = 'g', marker = '.',label = "availability_365")
  
plt.xticks(rotation = 25)
plt.xlabel('Host id')
plt.ylabel('availability_365')
plt.title('Availabililty Report', fontsize = 20)
plt.grid()
plt.legend()
plt.show()

# %%
class Entry:
    def __init__(self, id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365):
        self.id = id
        self.name = name
        self.host_id = host_id
        self.host_name = host_name
        self.neighbourhood_group = neighbourhood_group
        self.neighbourhood = neighbourhood
        self.latitude = latitude
        self.longitude = longitude
        self.room_type = room_type
        self.price = price
        self.minimum_nights = minimum_nights
        self.number_of_reviews = number_of_reviews
        self.last_review = last_review
        self.reviews_per_month = reviews_per_month
        self.calculated_host_listings_count = calculated_host_listings_count
        self.availability_365 = availability_365
        self.busyness = 0
        
    def set_busyness(self):
        price = self.price
        if price == 0:
            price = sys.float_info.epsilon
        self.busyness = float(self.calculated_host_listings_count)**3 * float(self.availability_365)**2 * float(self.number_of_reviews) / float(price)**4

    def get_busyness(self):
        self.set_busyness()
        return float(self.busyness)

# %%
entries = []
busyness = []
for i in range(dataset_size):
    entry = Entry(bnb['id'][i], bnb['name'][i], bnb['host_id'][i], bnb['host_name'][i], bnb['neighbourhood_group'][i], bnb['neighbourhood'][i], bnb['latitude'][i], bnb['longitude'][i], bnb['room_type'][i], bnb['price'][i], bnb['minimum_nights'][i], bnb['number_of_reviews'][i], bnb['last_review'][i], bnb['reviews_per_month'][i], bnb['calculated_host_listings_count'][i], bnb['availability_365'][i])
    entries.append(entry)
    b = entry.get_busyness()
    busyness.append(b)

# %%
x = bnb['host_id']
y = busyness

plt.scatter(x, y, color = 'g', marker = '.',label = "Busyness")
  
plt.xticks(rotation = 25)
plt.xlabel('Host id')
plt.ylabel('Busyness')
plt.title('Plot 3-1', fontsize = 20)
plt.grid()
plt.legend()
plt.show()

# %%
x = bnb['host_id']
y = bnb['price']
y2 = bnb['calculated_host_listings_count']

plt.scatter(x, y, color = 'g', marker = '.',label = "Price")
plt.scatter(x, y2, color = 'r', marker = '.',label = "Room Count")
  
plt.xlabel('Host id')
plt.title('Plot 4-1', fontsize = 20)
plt.grid()
plt.legend()
plt.show()
